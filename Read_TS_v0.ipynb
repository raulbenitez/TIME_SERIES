# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/TIME_SERIES/blob/main/Read_TS_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/raulbenitez/TIME_SERIES/main/DatosLastMile.csv',sep=',')
df.head(20)
# Out:
#          FECHA   NOTAS
# 0   2019-11-02  5614.0
# 1   2019-11-04  8265.0
# 2   2019-11-05  8418.0
# 3   2019-11-06  7597.0
# 4   2019-11-07  7345.0
# 5   2019-11-08  8132.0
# 6   2019-11-09  5061.0
# 7   2019-11-11  7061.0
# 8   2019-11-12  7481.0
# 9   2019-11-13  6781.0
# 10  2019-11-14  6225.0
# 11  2019-11-15  7549.0
# 12  2019-11-16  5088.0
# 13  2019-11-18  6634.0
# 14  2019-11-19  6685.0
# 15  2019-11-20  5958.0
# 16  2019-11-21  6268.0
# 17  2019-11-22  7841.0
# 18  2019-11-23  5270.0
# 19  2019-11-25  7734.0

# %%
df.columns
# Out:
# Index(['FECHA', 'NOTAS'], dtype='object')

# %%
df.shape
# Out:
# (616, 2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18,10))
sns.lineplot(x='FECHA',y='NOTAS',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Interactive plots with plotly

# %%
# Using plotly.express
import plotly.express as px

fig = px.line(df,x='FECHA',y='NOTAS')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="da7a0b75-48dc-4aa3-a1b0-b24c3d298199" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da7a0b75-48dc-4aa3-a1b0-b24c3d298199")) {
#                     Plotly.newPlot(
#                         'da7a0b75-48dc-4aa3-a1b0-b24c3d298199',
# ...

# %% [markdown]
# Fit an AR model

# %%
import statsmodels.api as sm

fig = sm.graphics.tsa.plot_pacf(df['NOTAS'], lags=40,method="ywm")

# %%
ar8_mod = sm.tsa.ARIMA(df['NOTAS'], (8,0,0))
ar8_results = ar8_mod.fit()
ar8_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  NOTAS   No. Observations:                  616
# Model:                     ARMA(8, 0)   Log Likelihood               -5303.000
# Method:                       css-mle   S.D. of innovations           1323.924
# Date:                Tue, 09 Nov 2021   AIC                          10625.999
# Time:                        15:01:50   BIC                          10670.232
# Sample:                             0   HQIC                         10643.198
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        8199.5295    256.961     31.910      0.000    7695.896    8703.163
# ar.L1.NOTAS     0.2788      0.040      6.889      0.000       0.199       0.358
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/raulbenitez/TIME_SERIES/main/DatosLastMile.csv',sep=',',index_col=0)

ar8_mod_1 = sm.tsa.ARIMA(df1, (8,0,0))
ar8_results1 = ar8_mod_1.fit()
ar8_results1.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  NOTAS   No. Observations:                  616
# Model:                     ARMA(8, 0)   Log Likelihood               -5303.000
# Method:                       css-mle   S.D. of innovations           1323.924
# Date:                Tue, 09 Nov 2021   AIC                          10625.999
# Time:                        15:13:28   BIC                          10670.232
# Sample:                             0   HQIC                         10643.198
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/raulbenitez/TIME_SERIES/main/Rincon_Viejo.csv',sep=';')
df2.describe()
# Out:
#        Prof NF (metros)
# count       3833.000000
# mean           2.529097
# std            0.949879
# min            0.360000
# 25%            2.030000
# 50%            2.710000
# 75%            3.250000
# max            4.300000

# %%
df2.head(20)
# Out:
#          Fecha  Prof NF (metros) Las Flores Precip (mm)
# 0   01/02/2007               NaN                    NaN
# 1   02/02/2007               NaN                    NaN
# 2   03/02/2007               NaN                    NaN
# 3   04/02/2007               NaN                     13
# 4   05/02/2007              3.01                    NaN
# 5   06/02/2007              3.01                      0
# 6   07/02/2007              3.04                      0
# 7   08/02/2007              3.05                      3
# 8   09/02/2007              3.06                      0
# 9   10/02/2007              3.08                      0
# 10  11/02/2007              3.09                      0
# 11  12/02/2007              3.10                      0
# 12  13/02/2007              3.10                      0
# 13  14/02/2007              3.13                      0
# 14  15/02/2007              3.14                     23
# 15  16/02/2007              3.15                      4
# ...

# %%
df2.columns
# Out:
# Index(['Fecha', 'Prof NF (metros)', 'Las Flores Precip (mm)'], dtype='object')

# %% [markdown]
# Remove column

# %%
df2.drop(['Las Flores Precip (mm)'],axis=1,inplace=True)
df2.head()
# Out:
#         Fecha  Prof NF (metros)
# 0  01/02/2007               NaN
# 1  02/02/2007               NaN
# 2  03/02/2007               NaN
# 3  04/02/2007               NaN
# 4  05/02/2007              3.01

# %%
df2.describe()
# Out:
#        Prof NF (metros)
# count       3833.000000
# mean           2.529097
# std            0.949879
# min            0.360000
# 25%            2.030000
# 50%            2.710000
# 75%            3.250000
# max            4.300000

# %%
df2.isna().sum()
# Out:
# Fecha                 0
# Prof NF (metros)    428
# dtype: int64

# %%
df2_filled = df2.interpolate(method='spline', order=1,limit=5)
df2_filled.head(20)
# Out:
#          Fecha  Prof NF (metros)
# 0   01/02/2007               NaN
# 1   02/02/2007               NaN
# 2   03/02/2007               NaN
# 3   04/02/2007               NaN
# 4   05/02/2007              3.01
# 5   06/02/2007              3.01
# 6   07/02/2007              3.04
# 7   08/02/2007              3.05
# 8   09/02/2007              3.06
# 9   10/02/2007              3.08
# 10  11/02/2007              3.09
# 11  12/02/2007              3.10
# 12  13/02/2007              3.10
# 13  14/02/2007              3.13
# 14  15/02/2007              3.14
# 15  16/02/2007              3.15
# 16  17/02/2007              3.16
# 17  18/02/2007              3.17
# 18  19/02/2007              3.18
# 19  20/02/2007              3.19
